# %%
import os
import sys
sys.path.append("./../src/")

# %%
from utilities import REPO_PATH, DATA_PATH, RESPONSE_COL_NAME, get_feature_corr_with_response

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.preprocessing import StandardScaler

#Neural Networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from scipy.stats import randint
# Out:
# WARNING:tensorflow:From c:\Users\david\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train = pd.read_csv(f"{DATA_PATH}/train.csv")
test = pd.read_csv(f"{DATA_PATH}/test.csv")
val = pd.read_csv(f"{DATA_PATH}/val.csv")

# %%
X_train, y_train = train.drop([RESPONSE_COL_NAME], axis=1), train[RESPONSE_COL_NAME]
y_test, X_test = test[RESPONSE_COL_NAME], test.drop([RESPONSE_COL_NAME],axis=1)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# Model #1: Random Forest

# %%
rf_classifier = RandomForestClassifier()

# %%
rf_classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_preds = rf_classifier.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_preds)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5

# %%
param_dict = {
    'n_estimators': range(5,30,5),
    'max_depth': range(10,30,5)
}

gridSearchClassifier = GridSearchCV(RandomForestClassifier(), param_dict)

gridSearchClassifier.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(10, 30, 5),
#                          'n_estimators': range(5, 30, 5)})

# %%
gridSearchClassifier.best_params_
# Out:
# {'max_depth': 20, 'n_estimators': 25}

# %%
y_preds_gridsearch = gridSearchClassifier.predict(X_test)
accuracy_after_gridsearch = accuracy_score(y_test, y_preds_gridsearch)
print("Accuracy:", accuracy_after_gridsearch)
# Out:
# Accuracy: 0.5

# %% [markdown]
# LazyClassifier

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True,custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
#  97%|█████████▋| 28/29 [01:21<00:01,  1.62s/it]
# [LightGBM] [Info] Number of positive: 17000, number of negative: 424
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006732 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2607
# [LightGBM] [Info] Number of data points in the train set: 17424, number of used features: 62
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.975666 -> initscore=3.691235
# [LightGBM] [Info] Start training from score 3.691235
# 100%|██████████| 29/29 [01:22<00:00,  2.85s/it]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.67               0.67     0.67      0.65
# NearestCentroid                    0.66               0.66     0.66      0.63
# LabelPropagation                   0.59               0.59     0.59      0.53
# LabelSpreading                     0.59               0.59     0.59      0.53
# DecisionTreeClassifier             0.57               0.57     0.57      0.50
# LGBMClassifier                     0.53               0.53     0.53      0.40
# ExtraTreeClassifier                0.52               0.52     0.52      0.41
# PassiveAggressiveClassifier        0.51               0.51     0.51      0.38
# BaggingClassifier                  0.51               0.51     0.51      0.35
# LinearDiscriminantAnalysis         0.50               0.50     0.50      0.35
# Perceptron                         0.50               0.50     0.50      0.34
# QuadraticDiscriminantAnalysis      0.50               0.50     0.50      0.33
# RidgeClassifierCV                  0.50               0.50     0.50      0.33
# SGDClassifier                      0.50               0.50     0.50      0.33
# RandomForestClassifier             0.50               0.50     0.50      0.33
# SVC                                0.50               0.50     0.50      0.33
# XGBClassifier                      0.50               0.50     0.50      0.33
# RidgeClassifier                    0.50               0.50     0.50      0.33
# AdaBoostClassifier                 0.50               0.50     0.50      0.33
# LogisticRegression                 0.50               0.50     0.50      0.33
# KNeighborsClassifier               0.50               0.50     0.50      0.33
# GaussianNB                         0.50               0.50     0.50      0.33
# ExtraTreesClassifier               0.50               0.50     0.50      0.33
# DummyClassifier                    0.50               0.50     0.50      0.33
# CalibratedClassifierCV             0.50               0.50     0.50      0.33
# LinearSVC                          0.50               0.50     0.50      0.33
#
#                                Time Taken
# Model
# BernoulliNB                          0.09
# NearestCentroid                      0.07
# LabelPropagation                    26.45
# LabelSpreading                      29.50
# DecisionTreeClassifier               0.46
# LGBMClassifier                       0.58
# ExtraTreeClassifier                  0.10
# PassiveAggressiveClassifier          0.11
# BaggingClassifier                    2.75
# LinearDiscriminantAnalysis           0.35
# Perceptron                           0.11
# QuadraticDiscriminantAnalysis        0.29
# RidgeClassifierCV                    0.29
# SGDClassifier                        0.18
# RandomForestClassifier               3.14
# SVC                                  3.99
# XGBClassifier                        3.02
# RidgeClassifier                      0.09
# AdaBoostClassifier                   1.96
# LogisticRegression                   0.17
# KNeighborsClassifier                 0.48
# GaussianNB                           0.08
# ExtraTreesClassifier                 2.12
# DummyClassifier                      0.06
# CalibratedClassifierCV               0.99
# LinearSVC                            4.96

# %% [markdown]
# Neural Networks

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Step 4: Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Step 5: Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss}, Test Accuracy: {test_accuracy}')
# Out:
# WARNING:tensorflow:From c:\Users\david\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\david\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\david\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\david\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 436/436 [==============================] - 2s 3ms/step - loss: 0.1574 - accuracy: 0.9551 - val_loss: 0.0312 - val_accuracy: 0.9991
# Epoch 2/10
# 436/436 [==============================] - 1s 2ms/step - loss: 0.1124 - accuracy: 0.9697 - val_loss: 0.0266 - val_accuracy: 0.9994
# Epoch 3/10
# 436/436 [==============================] - 1s 3ms/step - loss: 0.1054 - accuracy: 0.9700 - val_loss: 0.0351 - val_accuracy: 0.9986
# Epoch 4/10
# 436/436 [==============================] - 1s 2ms/step - loss: 0.1003 - accuracy: 0.9700 - val_loss: 0.0443 - val_accuracy: 0.9954
# Epoch 5/10
# 436/436 [==============================] - 1s 2ms/step - loss: 0.0961 - accuracy: 0.9707 - val_loss: 0.0328 - val_accuracy: 0.9989
# Epoch 6/10
# 436/436 [==============================] - 1s 2ms/step - loss: 0.0913 - accuracy: 0.9712 - val_loss: 0.0512 - val_accuracy: 0.9923
# Epoch 7/10
# 436/436 [==============================] - 1s 3ms/step - loss: 0.0872 - accuracy: 0.9728 - val_loss: 0.0216 - val_accuracy: 0.9986
# Epoch 8/10
# 436/436 [==============================] - 1s 3ms/step - loss: 0.0845 - accuracy: 0.9732 - val_loss: 0.0406 - val_accuracy: 0.9925
# Epoch 9/10
# 436/436 [==============================] - 1s 2ms/step - loss: 0.0802 - accuracy: 0.9750 - val_loss: 0.0246 - val_accuracy: 0.9971
# Epoch 10/10
# 436/436 [==============================] - 1s 3ms/step - loss: 0.0763 - accuracy: 0.9760 - val_loss: 0.0445 - val_accuracy: 0.9891
# 9/9 [==============================] - 0s 2ms/step - loss: 1.7161 - accuracy: 0.5321
# Test Loss: 1.7160850763320923, Test Accuracy: 0.5321428775787354
